# %% [markdown]
# # Measure cell metrics in across frames
# This script measures certain metrics (area, eccentricity, solidity, intensity) of each target cell across frames.
# Shape-related metrics (area, eccentricity, solidity) are obtained from the segmentation results, intensity-related metrics are obtained from the original images.
# All metrics are added to the tracking files, and stored within a `measurements` subfolder, within the `metrics` subfolder.
# Change the master folder path in code block 3 before running the code.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import tifffile
from skimage.measure import regionprops_table

import os
import re
import glob
from pathlib import Path

# %%
def metrics_from_timeseries(spots_path, concat_label_path, YFP_label_path, YFP_path, PI_path, output_folder):

    # Cleanup data
    spots_df['POSITION_X'] = pd.to_numeric(spots_df['POSITION_X'], errors='coerce')
    spots_df['POSITION_Y'] = pd.to_numeric(spots_df['POSITION_Y'], errors='coerce')
    spots_df['TRACK_ID'] = pd.to_numeric(spots_df['TRACK_ID'], errors='coerce')
    spots_df['FRAME'] = pd.to_numeric(spots_df['FRAME'], errors='coerce')

    spots_df.dropna(subset=['POSITION_X', 'POSITION_Y', 'TRACK_ID', 'FRAME'], inplace=True)

    sample_idx = re.findall(r'xy(\d+)', str(spots_path))[-1]  # For naming output files

    # Collect measurements
    all_measurements = []

    for i, row in spots_df.iterrows():
        frame = int(row['FRAME'])
        x = int(round(row['POSITION_X']))
        y = int(round(row['POSITION_Y']))
        source = row['SOURCE']

        # Load the label frame for the current timepoint
        concat_label_frame = concat_label_img[frame]
        YFP_label_frame = YFP_label_img[frame]

        # Ensure valid positions
        if 0 <= y < concat_label_frame.shape[0] and 0 <= x < concat_label_frame.shape[1]:
            nucleus_label_id = concat_label_frame[y, x]  # Get the nuclear label
        else:
            nucleus_label_id = 0

        if nucleus_label_id == 0:
            continue  # Skip background or invalid

        # Check if the cell is alive or dead based on the source
        if source == 'Live':
            # Get the corresponding cytoplasm label based on nucleus position
            cytoplasm_label_id = YFP_label_frame[y, x]
            # Create a binary mask for the cytoplasm
            if cytoplasm_label_id > 0:
                cytoplasm_mask = (YFP_label_frame == cytoplasm_label_id).astype(np.uint8)

            # Use the YFP channel for metric extraction
            intensity_frame = YFP_img[frame]

            # Calculate metrics exclusively for the cytoplasmic region
            if np.any(cytoplasm_mask):  # Proceed only if there's a cytoplasmic area
                props = regionprops_table(
                    cytoplasm_mask,
                    intensity_image=intensity_frame,
                    properties=[
                        'area',
                        'eccentricity',
                        'solidity',
                        'mean_intensity',
                        'max_intensity',
                        'min_intensity'
                    ]
                )

                prop_dict = {k: v[0] for k, v in props.items()}
                prop_dict.update({
                    'TRACK_ID': row['TRACK_ID'],
                    'FRAME': frame,
                    'ID': nucleus_label_id,
                    'SOURCE': source
                })

                all_measurements.append(prop_dict)

        elif source == 'Dead':
            # Directly use the dead cell label to get metrics from the PI channel
            # Create a binary mask for the dead cell
            dead_cell_mask = (concat_label_frame == nucleus_label_id).astype(np.uint8)

            # Use the PI channel for metrics extraction
            intensity_frame = PI_img[frame]

            # Calculate metrics for the dead cells
            if np.any(dead_cell_mask):  # Proceed only if there's a dead cell area
                props = regionprops_table(
                    dead_cell_mask,
                    intensity_image=intensity_frame,
                    properties=[
                        'area',
                        'eccentricity',
                        'solidity',
                        'mean_intensity',
                        'max_intensity',
                        'min_intensity'
                    ]
                )

                prop_dict = {k: v[0] for k, v in props.items()}
                prop_dict.update({
                    'TRACK_ID': row['TRACK_ID'],
                    'FRAME': frame,
                    'ID': nucleus_label_id, 
                    'SOURCE': source
                })

                all_measurements.append(prop_dict)

    # Save results
    results_df = pd.DataFrame(all_measurements)
    results_df.to_csv(os.path.join(output_folder, f'sample{sample_idx}_dual_channel_metrics.csv'), index=False)

    return results_df

# %%
# Batch collect metrics
master_folder = '/home/vil945/live_cell_imaging/2025-06-18_live_cell_imaging'

# DO NOT change anything beyond this line
# Create output folder to store measurements
exp_date = re.search(r"\d{4}-\d{2}-\d{2}", master_folder)[0]
output_folder = os.path.join(master_folder, f'{exp_date}_metrics', f'{exp_date}_measurements')
os.makedirs(output_folder, exist_ok=True)


tracking_files = glob.glob(os.path.join(master_folder, '*tracking*', '*combined_spots_relabeled*', '*.csv')) # find target cells tracking files
# Find sample indices from all tracking files
sample_indices = []
for f in tracking_files:
    m = re.search(r'(sample\d+(?:_.+?)?)_target_combined_spots\.csv', os.path.basename(f))
    if m:
        sample_indices.append(m.group(1))
sample_indices = sorted(set(sample_indices))

# Find tracking file, YFP image, YFP labels, PI image, nuclear labels
for idx in sample_indices:
    print(f'Processing {idx}...')
    # 1. Tracking
    tracking_fn = glob.glob(os.path.join(master_folder, '*tracking*', '*combined_spots_relabeled*', f'*{idx}_target_combined_spots_relabeled.csv'))
    # 2. YFP image
    YFP_img_fn = glob.glob(os.path.join(master_folder, '*YFP*', f'*{idx}_YFP*.tif'))
    # 3. YFP mask
    YFP_mask_fn = glob.glob(os.path.join(master_folder, '*YFP*', '*YFP_segmented*', f'*segmented*{idx}_YFP*.tif'))
    # 4. PI image
    PI_img_fn = glob.glob(os.path.join(master_folder, '*PI*', f'*{idx}_PI*.tif'))
    # 5. Nuclear mask
    nuc_mask_fn = glob.glob(os.path.join(master_folder, '*filtered_segmentation*', '*concatenated_segmentation*', f'*{idx}_target_concatenated*.tif'))

    # Basic file existence check
    if not (tracking_fn and YFP_img_fn and YFP_mask_fn and nuc_mask_fn):
        print(f"Missing files for {idx}! Skipping.")
        continue

    # Expand globs
    tracking_fn, YFP_img_fn, YFP_mask_fn, PI_img_fn, nuc_mask_fn = \
        tracking_fn[0], YFP_img_fn[0], YFP_mask_fn[0], PI_img_fn[0], nuc_mask_fn[0]

    # Read files
    tracking_df = pd.read_csv(tracking_fn)
    YFP_img_stack = imread(YFP_img_fn)    # intensity, shape (frames, Y, X)
    YFP_mask_stack = imread(YFP_mask_fn)  # mask, same shape as above
    PI_img_stack = imread(PI_img_fn)      # intensity, shape as above
    nuc_mask_stack = imread(nuc_mask_fn)  # mask, same shape as above

    metrics_df = metrics_from_timeseries(tracking_df, nuc_mask_stack, YFP_mask_stack, YFP_img_stack, PI_img_stack, output_folder) # Call record metrics function
